# %% [markdown]
# <a href="https://colab.research.google.com/github/harithiduwara/AluthKade/blob/main/turtle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First you have to install ColabTurtle

# %%
# !pip install ColabTurtlePlus
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip3 install ColabTurtle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# Import ColabTurtle.Turtle

# %%
from ColabTurtle.Turtle import *
from ColabTurtlePlus.Turtle import *
import random
# Out:
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell

# %% [markdown]
# Then you need to intilise a turtle

# %%
initializeTurtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %% [markdown]
# Do what ever you want!

# %%
speed(10)
colors = ["cyan", "yellow", "red", "blue", "orange"]
color(random.choice(colors))
bgcolor('black')

b = 200
while b>0:
  left(b)
  forward(b*3)
  b = b-1
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
colors = ["red", "violet", "blue", "yellow", "green"]

pen()
bgcolor("black")

for i in range(100):
  pencolor = colors[i%5]
  width(i/50+1)
  forward(i)
  left(19)

done()
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:black;stroke:;stroke-width:1"/>
#
#
# ...
